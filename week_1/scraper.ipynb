# %% [markdown]
# # Advanced Machine Learning – Natural Language Processing
# By: **Ivan Runov** & **Sebastiaan Craens** (group 8)
#
# ### Practical Assignment 1: Web Scraping
#
# Build an automated pipeline that:
# - Collects book links from the public ranking page
# - Visits individual book pages to extract relevant properties (metadata)
# - Downloads the plain text versions of all English books
# - Stores the data in a structured and reproducible way
# By doing so, you will simulate a simplified version of a web data ingestion workflow as used in industry and research.
#
# You will use the stored texts and properties in subsequent assignments in this course.

# %% [markdown]
# ### Imports

# %%
import io
import os
import re
import json
import requests
import pandas as pd
from bs4 import BeautifulSoup
from urllib.parse import urljoin
#https://books.flotwiskunde.nl

# %% [markdown]
# ### Settings

# %%
# Page containing top 100 EBooks of the last 30 days
TOP_URL = "https://books.flotwiskunde.nl/browse/scores/top"
# Our target list is below this header (id determined using the browser's developer tools)
LIST_HEADER_TAG = "h2"
LIST_HEADER_ID = "books-last30"
# Metadata table (id determined using the browser's developer tools)
METADATA_TABLE_ID = "about_book_table"

# User-Agent header identifies the scraper as a Python script.
HEADERS = {"User-Agent": "Python Requests"}

# Output directories
OUT_DIR = "data" # Stores metadata
TEXT_DIR = os.path.join(OUT_DIR, "texts") # Stores downloaded plaintext files

# %% [markdown]
# ### Setup

# %%
# Ensure existence of output directories
os.makedirs(OUT_DIR, exist_ok=True)
os.makedirs(TEXT_DIR, exist_ok=True)

# Function for getting soup (requesting and parsing a page)
def get_soup(url: str) -> BeautifulSoup:
    """Request a page and return its BeautifulSoup object."""
    response = requests.get(url, headers=HEADERS)
    response.raise_for_status() # Raise an error for bad responses
    return BeautifulSoup(response.text, "html.parser")

# Functions for coloring terminal output (for better readability)
def red(text: str) -> str:
    """Return text wrapped in ANSI codes for red color."""
    return f"\033[91m{text}\033[0m"
def green(text: str) -> str:
    """Return text wrapped in ANSI codes for green color."""
    return f"\033[92m{text}\033[0m"
def red_or_green(text: str, condition: bool) -> str:
    """Return text colored green if condition is True, else red."""
    return green(text) if condition else red(text)

# %% [markdown]
# ### Scraping the list

# %%
# Get the top page and parse it using BeautifulSoup.
soup = get_soup(TOP_URL)

# Find the specific header
target_header = soup.find(LIST_HEADER_TAG, id=LIST_HEADER_ID)
assert target_header is not None, f"Could not find header '{LIST_HEADER_ID}' in the page"
print(f"Found target header: {target_header}")

# From our scouting we know that this header is followed by an ordered list (<ol>) containing the top 100 books.
for sibling in target_header.find_next_siblings():
    if sibling.name == "ol":
        top_books = sibling.find_all("a", href=True)
        print(f"List containing {len(top_books)} links found:")
        print('\n'.join([str(book) for book in top_books[:3]]) + '\n...')
        break
else:
    raise ValueError("Could not find the ordered list of top 100 books.")
# Out:
# Found target header: <h2 id="books-last30">Top 100 EBooks last 30 days</h2>
# List containing 100 links found:
# <a href="/ebooks/84.html">Frankenstein; Or, The Modern Prometheus by Mary Wollstonecraft Shelley (145303)</a>
# <a href="/ebooks/2701.html">Moby Dick; Or, The Whale by Herman Melville (115857)</a>
# <a href="/ebooks/1342.html">Pride and Prejudice by Jane Austen (85439)</a>
# ...

# %% [markdown]
# ### Scraping the books

# %%
print(f"Processing books...")

metadata_list = []
# Iterate over the list of top books and process each one.
# The metadata is saved in a list of dictionaries, which we will save at the end.
for i, book in enumerate(top_books, start=1):
    url = urljoin(TOP_URL, book['href'])
    print(f"[{i}/{len(top_books)}] ({url})", end = '')
        
    # Get the book's page and parse it
    soup = get_soup(url)
    
    # Find metadata table
    table_id = "about_book_table"
    meta_table = soup.find("table", id=table_id)
    assert meta_table is not None, f"Could not find metadata table with id '{table_id}' in page {url}"
    
    # Parse metadata table using pandas and convert into dictionary
    meta = pd.read_html(io.StringIO(str(meta_table)))[0].set_index(0).loc[:, 1].to_dict()
    
    # Skip book if not English
    if meta["Language"] != "English":
        print(red(f" Not English => Skipping..."))
        continue
        
    # Get relevant metadata (using .get() to avoid KeyErrors for missing fields)
    meta_relevant = {
        "url":                   url,
        "title":                 meta.get("Title", ""),
        # "author":                meta.get("Author", ""),
        # "credits":               meta.get("Credits", ""),
        "reading_level":         meta.get("Reading Level", ""),
        "ebook_no":              meta.get("EBook-No.", ""),
        "language":              meta.get("Language", ""),
        "release_date":          meta.get("Release Date", ""),
        "most_recently_updated": meta.get("Most Recently Updated", ""),
        "downloads":             meta.get("Downloads", ""),
    }
    
    # Find plaintext download link (if available)
    download_link = soup.find("a", string="Plain Text UTF-8")
    if download_link is not None:
        meta_relevant["plaintext_url"] = urljoin(url, download_link['href'])
    else:
        print(red(f" No plaintext download => Skipping..."))
        continue
    
    # Download plaintext file
    try:
        # Request the plaintext file
        txt_resp = requests.get(meta_relevant["plaintext_url"], headers=HEADERS)
        txt_resp.raise_for_status()
        txt_resp.encoding = "utf-8" # Ensure correct encoding
        
        # Save the plaintext file
        out_path = os.path.join(TEXT_DIR, f"{meta_relevant['ebook_no']}.txt")
        with open(out_path, "w", encoding="utf-8") as f:
            f.write(txt_resp.text)

        # Print success message
        print(green(f" Downloaded text => Saved to {out_path}"))
    
    # May fail for whatever reason
    except Exception as e:
        print(red(f" Failed to download text: {e}"))
    
    # Append relevant metadata to list
    metadata_list.append(meta_relevant)

print(f"Books processed: {len(metadata_list)}/{len(top_books)}")


# Save metadata as csv
print(f"Saving metadata as csv...", end="\r")
meta_df = pd.DataFrame(metadata_list)
meta_df.to_csv(os.path.join(OUT_DIR, "metadata.csv"), index=False)
print(f"Saving metadata as csv... Done.")

# Save metadata as jsonl (one JSON record per line)
print(f"Saving metadata as jsonl...", end="\r")
with open(os.path.join(OUT_DIR, "metadata.jsonl"), "w", encoding="utf-8") as f:
    for rec in metadata_list:
        f.write(json.dumps(rec, ensure_ascii=False) + "\n")
print(f"Saving metadata as jsonl... Done.")
# Out:
# Processing books...
# [1/100] (https://books.flotwiskunde.nl/ebooks/84.html) Downloaded text => Saved to data\texts\84.txt
# [2/100] (https://books.flotwiskunde.nl/ebooks/2701.html) Downloaded text => Saved to data\texts\2701.txt
# [3/100] (https://books.flotwiskunde.nl/ebooks/1342.html) Downloaded text => Saved to data\texts\1342.txt
# [4/100] (https://books.flotwiskunde.nl/ebooks/1513.html) Downloaded text => Saved to data\texts\1513.txt
# [5/100] (https://books.flotwiskunde.nl/ebooks/26184.html) Downloaded text => Saved to data\texts\26184.txt
# [6/100] (https://books.flotwiskunde.nl/ebooks/100.html) Downloaded text => Saved to data\texts\100.txt
# [7/100] (https://books.flotwiskunde.nl/ebooks/2641.html) Downloaded text => Saved to data\texts\2641.txt
# [8/100] (https://books.flotwiskunde.nl/ebooks/43.html) Downloaded text => Saved to data\texts\43.txt
# [9/100] (https://books.flotwiskunde.nl/ebooks/145.html) Downloaded text => Saved to data\texts\145.txt
# [10/100] (https://books.flotwiskunde.nl/ebooks/11.html) Downloaded text => Saved to data\texts\11.txt
# [11/100] (https://books.flotwiskunde.nl/ebooks/37106.html) Downloaded text => Saved to data\texts\37106.txt
# [12/100] (https://books.flotwiskunde.nl/ebooks/2554.html) Downloaded text => Saved to data\texts\2554.txt
# [13/100] (https://books.flotwiskunde.nl/ebooks/768.html) Downloaded text => Saved to data\texts\768.txt
# [14/100] (https://books.flotwiskunde.nl/ebooks/1260.html) Downloaded text => Saved to data\texts\1260.txt
# [15/100] (https://books.flotwiskunde.nl/ebooks/67979.html) Downloaded text => Saved to data\texts\67979.txt
# [16/100] (https://books.flotwiskunde.nl/ebooks/16389.html) Downloaded text => Saved to data\texts\16389.txt
# [17/100] (https://books.flotwiskunde.nl/ebooks/16328.html) Downloaded text => Saved to data\texts\16328.txt
# [18/100] (https://books.flotwiskunde.nl/ebooks/64317.html) Downloaded text => Saved to data\texts\64317.txt
# [19/100] (https://books.flotwiskunde.nl/ebooks/394.html) Downloaded text => Saved to data\texts\394.txt
# [20/100] (https://books.flotwiskunde.nl/ebooks/6761.html) Downloaded text => Saved to data\texts\6761.txt
# [21/100] (https://books.flotwiskunde.nl/ebooks/2160.html) Downloaded text => Saved to data\texts\2160.txt
# [22/100] (https://books.flotwiskunde.nl/ebooks/5197.html) Downloaded text => Saved to data\texts\5197.txt
# [23/100] (https://books.flotwiskunde.nl/ebooks/1259.html) Downloaded text => Saved to data\texts\1259.txt
# [24/100] (https://books.flotwiskunde.nl/ebooks/4085.html) Downloaded text => Saved to data\texts\4085.txt
# [25/100] (https://books.flotwiskunde.nl/ebooks/6593.html) Downloaded text => Saved to data\texts\6593.txt
# [26/100] (https://books.flotwiskunde.nl/ebooks/8492.html) Downloaded text => Saved to data\texts\8492.txt
# [27/100] (https://books.flotwiskunde.nl/ebooks/174.html) Downloaded text => Saved to data\texts\174.txt
# [28/100] (https://books.flotwiskunde.nl/ebooks/1184.html) Downloaded text => Saved to data\texts\1184.txt
# [29/100] (https://books.flotwiskunde.nl/ebooks/1080.html) Downloaded text => Saved to data\texts\1080.txt
# [30/100] (https://books.flotwiskunde.nl/ebooks/844.html) Downloaded text => Saved to data\texts\844.txt
# [31/100] (https://books.flotwiskunde.nl/ebooks/2542.html) Downloaded text => Saved to data\texts\2542.txt
# [32/100] (https://books.flotwiskunde.nl/ebooks/98.html) Downloaded text => Saved to data\texts\98.txt
# [33/100] (https://books.flotwiskunde.nl/ebooks/345.html) Downloaded text => Saved to data\texts\345.txt
# [34/100] (https://books.flotwiskunde.nl/ebooks/74.html) Downloaded text => Saved to data\texts\74.txt
# [35/100] (https://books.flotwiskunde.nl/ebooks/28054.html) Downloaded text => Saved to data\texts\28054.txt
# [36/100] (https://books.flotwiskunde.nl/ebooks/76.html) Downloaded text => Saved to data\texts\76.txt
# [37/100] (https://books.flotwiskunde.nl/ebooks/1661.html) Downloaded text => Saved to data\texts\1661.txt
# [38/100] (https://books.flotwiskunde.nl/ebooks/1998.html) Downloaded text => Saved to data\texts\1998.txt
# [39/100] (https://books.flotwiskunde.nl/ebooks/25344.html) Downloaded text => Saved to data\texts\25344.txt
# [40/100] (https://books.flotwiskunde.nl/ebooks/1952.html) Downloaded text => Saved to data\texts\1952.txt
# [41/100] (https://books.flotwiskunde.nl/ebooks/3207.html) Downloaded text => Saved to data\texts\3207.txt
# [42/100] (https://books.flotwiskunde.nl/ebooks/6130.html) Downloaded text => Saved to data\texts\6130.txt
# [43/100] (https://books.flotwiskunde.nl/ebooks/1400.html) Downloaded text => Saved to data\texts\1400.txt
# [44/100] (https://books.flotwiskunde.nl/ebooks/1232.html) Downloaded text => Saved to data\texts\1232.txt
# [45/100] (https://books.flotwiskunde.nl/ebooks/36034.html) Downloaded text => Saved to data\texts\36034.txt
# [46/100] (https://books.flotwiskunde.nl/ebooks/205.html) Downloaded text => Saved to data\texts\205.txt
# [47/100] (https://books.flotwiskunde.nl/ebooks/2591.html) Downloaded text => Saved to data\texts\2591.txt
# [48/100] (https://books.flotwiskunde.nl/ebooks/46.html) Downloaded text => Saved to data\texts\46.txt
# [49/100] (https://books.flotwiskunde.nl/ebooks/2600.html) Downloaded text => Saved to data\texts\2600.txt
# [50/100] (https://books.flotwiskunde.nl/ebooks/3206.html) Downloaded text => Saved to data\texts\3206.txt
# [51/100] (https://books.flotwiskunde.nl/ebooks/4300.html) Downloaded text => Saved to data\texts\4300.txt
# [52/100] (https://books.flotwiskunde.nl/ebooks/5200.html) Downloaded text => Saved to data\texts\5200.txt
# [53/100] (https://books.flotwiskunde.nl/ebooks/4363.html) Downloaded text => Saved to data\texts\4363.txt
# [54/100] (https://books.flotwiskunde.nl/ebooks/45.html) Downloaded text => Saved to data\texts\45.txt
# [55/100] (https://books.flotwiskunde.nl/ebooks/3296.html) Downloaded text => Saved to data\texts\3296.txt
# [56/100] (https://books.flotwiskunde.nl/ebooks/120.html) Downloaded text => Saved to data\texts\120.txt
# [57/100] (https://books.flotwiskunde.nl/ebooks/45109.html) Downloaded text => Saved to data\texts\45109.txt
# [58/100] (https://books.flotwiskunde.nl/ebooks/7370.html) Downloaded text => Saved to data\texts\7370.txt
# [59/100] (https://books.flotwiskunde.nl/ebooks/27673.html) Downloaded text => Saved to data\texts\27673.txt
# [60/100] (https://books.flotwiskunde.nl/ebooks/1727.html) Downloaded text => Saved to data\texts\1727.txt
# [61/100] (https://books.flotwiskunde.nl/ebooks/5740.html) No plaintext download => Skipping...
# [62/100] (https://books.flotwiskunde.nl/ebooks/2680.html) Downloaded text => Saved to data\texts\2680.txt
# [63/100] (https://books.flotwiskunde.nl/ebooks/55.html) Downloaded text => Saved to data\texts\55.txt
# [64/100] (https://books.flotwiskunde.nl/ebooks/1497.html) Downloaded text => Saved to data\texts\1497.txt
# [65/100] (https://books.flotwiskunde.nl/ebooks/408.html) Downloaded text => Saved to data\texts\408.txt
# [66/100] (https://books.flotwiskunde.nl/ebooks/1399.html) Downloaded text => Saved to data\texts\1399.txt
# [67/100] (https://books.flotwiskunde.nl/ebooks/7290.html) Not English => Skipping...
# [68/100] (https://books.flotwiskunde.nl/ebooks/25162.html) Not English => Skipping...
# [69/100] (https://books.flotwiskunde.nl/ebooks/8800.html) Downloaded text => Saved to data\texts\8800.txt
# [70/100] (https://books.flotwiskunde.nl/ebooks/23.html) Downloaded text => Saved to data\texts\23.txt
# [71/100] (https://books.flotwiskunde.nl/ebooks/16119.html) Not English => Skipping...
# [72/100] (https://books.flotwiskunde.nl/ebooks/72679.html) Downloaded text => Saved to data\texts\72679.txt
# [73/100] (https://books.flotwiskunde.nl/ebooks/2148.html) Downloaded text => Saved to data\texts\2148.txt
# [74/100] (https://books.flotwiskunde.nl/ebooks/13240.html) Downloaded text => Saved to data\texts\13240.txt
# [75/100] (https://books.flotwiskunde.nl/ebooks/2852.html) Downloaded text => Saved to data\texts\2852.txt
# [76/100] (https://books.flotwiskunde.nl/ebooks/244.html) Downloaded text => Saved to data\texts\244.txt
# [77/100] (https://books.flotwiskunde.nl/ebooks/161.html) Downloaded text => Saved to data\texts\161.txt
# [78/100] (https://books.flotwiskunde.nl/ebooks/135.html) Downloaded text => Saved to data\texts\135.txt
# [79/100] (https://books.flotwiskunde.nl/ebooks/7241.html) Downloaded text => Saved to data\texts\7241.txt
# [80/100] (https://books.flotwiskunde.nl/ebooks/34901.html) Downloaded text => Saved to data\texts\34901.txt
# [81/100] (https://books.flotwiskunde.nl/ebooks/996.html) Downloaded text => Saved to data\texts\996.txt
# [82/100] (https://books.flotwiskunde.nl/ebooks/41445.html) Downloaded text => Saved to data\texts\41445.txt
# [83/100] (https://books.flotwiskunde.nl/ebooks/30254.html) Downloaded text => Saved to data\texts\30254.txt
# [84/100] (https://books.flotwiskunde.nl/ebooks/36459.html) Not English => Skipping...
# [85/100] (https://books.flotwiskunde.nl/ebooks/1600.html) Downloaded text => Saved to data\texts\1600.txt
# [86/100] (https://books.flotwiskunde.nl/ebooks/219.html) Downloaded text => Saved to data\texts\219.txt
# [87/100] (https://books.flotwiskunde.nl/ebooks/15399.html) Downloaded text => Saved to data\texts\15399.txt
# [88/100] (https://books.flotwiskunde.nl/ebooks/1023.html) Downloaded text => Saved to data\texts\1023.txt
# [89/100] (https://books.flotwiskunde.nl/ebooks/26.html) Downloaded text => Saved to data\texts\26.txt
# [90/100] (https://books.flotwiskunde.nl/ebooks/829.html) Downloaded text => Saved to data\texts\829.txt
# [91/100] (https://books.flotwiskunde.nl/ebooks/16.html) Downloaded text => Saved to data\texts\16.txt
# [92/100] (https://books.flotwiskunde.nl/ebooks/20228.html) Not English => Skipping...
# [93/100] (https://books.flotwiskunde.nl/ebooks/1524.html) Downloaded text => Saved to data\texts\1524.txt
# [94/100] (https://books.flotwiskunde.nl/ebooks/19942.html) Downloaded text => Saved to data\texts\19942.txt
# [95/100] (https://books.flotwiskunde.nl/ebooks/3090.html) Downloaded text => Saved to data\texts\3090.txt
# [96/100] (https://books.flotwiskunde.nl/ebooks/132.html) Downloaded text => Saved to data\texts\132.txt
# [97/100] (https://books.flotwiskunde.nl/ebooks/2814.html) Downloaded text => Saved to data\texts\2814.txt
# [98/100] (https://books.flotwiskunde.nl/ebooks/75883.html) Downloaded text => Saved to data\texts\75883.txt
# [99/100] (https://books.flotwiskunde.nl/ebooks/10676.html) Downloaded text => Saved to data\texts\10676.txt
# [100/100] (https://books.flotwiskunde.nl/ebooks/514.html) Downloaded text => Saved to data\texts\514.txt
# Books processed: 94/100
# Saving metadata as csv... Done.
# Saving metadata as jsonl... Done.
